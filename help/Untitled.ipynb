# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
# %matplotlib inline
import ipywidgets as widgets
import datetime
from IPython.display import display

# %%
car = pd.read_csv('carr.csv', sep=';')
siege= pd.read_csv('siegeee.csv', sep=';')
receipt1 = pd.read_csv('receipt11111.csv', sep=';')
receipt2 = pd.read_csv('receipt222222.csv', sep=';')
receipt=pd.concat([receipt1,receipt2],ignore_index=True)

# %%
car
# Out:
#    number_c     marka  year
# 0     74647      Audi  2008
# 1     63753       BMW  2001
# 2     74828  Mersedes  2004
# 3     72824     Volvo  2012

# %%
siege
# Out:
#    nomer#      Title  prise
# 0    6366  operasia1   1788
# 1    7738  operasia2   2000
# 2    7473  operasia3    377
# 3    7483  operasia4    377

# %%
receipt1
# Out:
#    number_с  number  nomeroperasii
# 0     74647    6366            123
# 1     63753    7738            345
# 2     74828    7473            847
# 3     72824    7483            874

# %%
receipt2
# Out:
#    number_с  number  nomeroperasii
# 0     74738    6096            638
# 1     77353    7738            335
# 2     72828    7429            838
# 3     72284    7383            832

# %%
receipt
# Out:
#    number_с  number  nomeroperasii
# 0     74647    6366            123
# 1     63753    7738            345
# 2     74828    7473            847
# 3     72824    7483            874
# 4     74738    6096            638
# 5     77353    7738            335
# 6     72828    7429            838
# 7     72284    7383            832

# %%
#A
dt=receipt.merge(car,left_on='number_с', right_on='number_c')
#print(dt)
dt=dt.merge(siege,left_on='number',right_on='nomer#')
#print(dt)
dt['prise'].sum()
# Out:
#    number_с  number  nomeroperasii  number_c     marka  year
# 0     74647    6366            123     74647      Audi  2008
# 1     63753    7738            345     63753       BMW  2001
# 2     74828    7473            847     74828  Mersedes  2004
# 3     72824    7483            874     72824     Volvo  2012
#    number_с  number  nomeroperasii  number_c     marka  year  nomer#  \
# 0     74647    6366            123     74647      Audi  2008    6366
# 1     63753    7738            345     63753       BMW  2001    7738
# 2     74828    7473            847     74828  Mersedes  2004    7473
# 3     72824    7483            874     72824     Volvo  2012    7483
#
#        Title  prise
# 0  operasia1   1788
# 1  operasia2   2000
# 2  operasia3    377
# 3  operasia4    377

# %%
#Б
dt=dt.groupby('number_с').sum().reset_index()
P
dt=dt[['marka','prise']]
dt
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [67], in <cell line: 3>()
#       1 #Б
#       2 dt=dt.groupby('number_с').sum().reset_index()
# ----> 3 dt=dt[['marka','prise']]
#       4 dt
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
# ...

# %%
#Г
y=dt.plot(x='marka',y='prise',kind='bar')
